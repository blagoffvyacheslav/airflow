# %% [markdown]
# __1.__ Какой из флагов утилиты crontab покажет список существующих кронов?
#
# Ответ: crontab -l

# %% [markdown]
# __2.__ Напишите крон, который будет запускаться каждую пятницу в 9 часов вечера.
#
# 0 21 * * 5

# %% [markdown]
# __3.__ Напишите крон, который будет запускаться каждое воскресенье марта месяца на протяжении всего дня с интервалом в 4 часа (т.е. запуск будет в 2021-03-07 00:00:00, затем 2021-03-07 04:00:00 и т.д.)
#
# 0 */4 * 3 7

# %% [markdown]
# __4.__ Отметьте все картинки, где изображен направленный ациклический граф.
#
# 1,3

# %% [markdown]
# __5.__ Опишите своими словами, как Вы поняли, чем отличается task от operator?
#
# Ответ: Мне кажется, оператор - это цель какого-либо мероприятия, состоящего из частей.
#     Например, если углубиться в математику и рассматривать линейный оператор - это отображение.
#     Мы берем каждый элемент и сопосталяем ему подходящий по правилу. Тем самым, это уже несколько подзадач.
#     Возвращаясь к датаплайнам, это какие-то операции, которые хотелось бы рассматриать атомарно (чтобы они были выполнены целиком или откатаны (транзакционно, если рассматривать теорию БД))
#     Например, ежедневная задача списания денег с рекуррентным платежем - это авторизация в платежной системе, снятие денег и манипуляция с БД, чтобы начислить деньги.
#     Вот уже три подзадачи в рамках одного оператора.
